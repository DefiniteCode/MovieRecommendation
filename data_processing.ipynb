# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("tmdb_2024.csv")
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
df.shape
# Out:
# (1256578, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256578 entries, 0 to 1256577
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1256578 non-null  int64
#  1   title                 1256565 non-null  object
#  2   vote_average          1256578 non-null  float64
#  3   vote_count            1256578 non-null  int64
#  4   status                1256578 non-null  object
#  5   release_date          1016582 non-null  object
#  6   revenue               1256578 non-null  int64
#  7   runtime               1256578 non-null  int64
#  8   adult                 1256578 non-null  bool
#  9   backdrop_path         324445 non-null   object
#  10  budget                1256578 non-null  int64
#  11  homepage              131135 non-null   object
#  12  imdb_id               630772 non-null   object
#  13  original_language     1256578 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
#select relevant columns
relevant_cols = ["id","title","genres","keywords","overview","original_language",
                 "popularity","release_date","vote_average","status","vote_count","poster_path"]

# %%
# creating a subset of the df with only relevant columns
df = df[relevant_cols]
df.head()
# Out:
#        id            title                                       genres  \
# 0   27205        Inception           Action, Science Fiction, Adventure
# 1  157336     Interstellar            Adventure, Drama, Science Fiction
# 2     155  The Dark Knight               Drama, Action, Crime, Thriller
# 3   19995           Avatar  Action, Adventure, Fantasy, Science Fiction
# 4   24428     The Avengers           Science Fiction, Action, Adventure
#
#                                             keywords  \
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
#                                             overview original_language  \
# 0  Cobb, a skilled thief who commits corporate es...                en
# ...

# %%
# coverting release dat to actual date format
df["release_date"] = pd.to_datetime(df["release_date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256578 entries, 0 to 1256577
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   id                 1256578 non-null  int64
#  1   title              1256565 non-null  object
#  2   genres             729010 non-null   object
#  3   keywords           326121 non-null   object
#  4   overview           985102 non-null   object
#  5   original_language  1256578 non-null  object
#  6   popularity         1256578 non-null  float64
#  7   release_date       1016582 non-null  datetime64[ns]
#  8   vote_average       1256578 non-null  float64
#  9   status             1256578 non-null  object
#  10  vote_count         1256578 non-null  int64
#  11  poster_path        837135 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 115.0+ MB

# %%
# check for nulls
df.isna().sum()
# Out:
# id                        0
# title                    13
# genres               527568
# keywords             930457
# overview             271476
# original_language         0
# popularity                0
# release_date         239996
# vote_average              0
# status                    0
# vote_count                0
# poster_path          419443
# dtype: int64

# %%
#drop all columns with nulls - the working df
df.dropna(inplace=True)

# %%
# check for nulls again
df.isna().sum()
# Out:
# id                   0
# title                0
# genres               0
# keywords             0
# overview             0
# original_language    0
# popularity           0
# release_date         0
# vote_average         0
# status               0
# vote_count           0
# poster_path          0
# dtype: int64

# %%
#checking the distinct no. of status we have
df["status"].unique()
# Out:
# array(['Released', 'In Production', 'Post Production', 'Planned',
#        'Rumored'], dtype=object)

# %%
# create a copy of the dataframe as the dataframe and filter for only released movies
working_df = df[df["status"] == "Released"]
working_df.head()
# Out:
#        id            title                                       genres  \
# 0   27205        Inception           Action, Science Fiction, Adventure
# 1  157336     Interstellar            Adventure, Drama, Science Fiction
# 2     155  The Dark Knight               Drama, Action, Crime, Thriller
# 3   19995           Avatar  Action, Adventure, Fantasy, Science Fiction
# 4   24428     The Avengers           Science Fiction, Action, Adventure
#
#                                             keywords  \
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
#                                             overview original_language  \
# 0  Cobb, a skilled thief who commits corporate es...                en
# ...

# %%
working_df.status.unique()
# Out:
# array(['Released'], dtype=object)

# %%
working_df.sort_values(by="release_date", ascending=False).head()
# Out:
#              id                          title                    genres  \
# 716353  1277126              Jude on 17 memory           Horror, Romance
# 742621  1355206           Lollipop Brainfreeze  Crime, Comedy, Adventure
# 623056  1507580  National Theatre Live: Hamlet                     Drama
# 555680  1419306                          Angel                    Comedy
# 571833  1436118             Friend of the Year                     Drama
#
#                                                  keywords  \
# 716353  aggressive, lighthearted, critical, romantic, ...
# 742621  robbery, drugs, road movie, bright color, viol...
# 623056                  stage play, west end, shakespeare
# 555680                         dark comedy, grief, family
# 571833         teen drama, young adult, party, freindship
#
#                                                  overview original_language  \
# 716353  Jude, trying to run fortnite on his trash ass ...                en
# ...

# %%
# mwe have some movies with release_date in the future so lets filter them as well
working_df = working_df[working_df["release_date"] <= "2025-04-22"].sort_values(by="release_date", ascending=False)

# %%
working_df.head()
# Out:
#              id                      title          genres  \
# 663699  1471989                    88 days        Thriller
# 625587  1513321               Curious Love         Romance
# 235483  1467898        Call of the Vulture   Drama, Comedy
# 288442  1468429  Being Friends with a Rock  Comedy, Action
# 328029  1494858                   Sunburst   Comedy, Drama
#
#                                                  keywords  \
# 663699                                   time loop, guilt
# 625587                                    lesbian erotica
# 235483  friendship, haunted by the past, rise to fame,...
# 288442                          revenge, buddy film, rock
# 328029                    dry, student film, black comedy
#
#                                                  overview original_language  \
# 663699  Damien, a young man recently widowed, wakes up...                en
# 625587  Charming blonde Sweet Lina is lounging on the ...                en
# ...

# %%
# create a tags column which is a combination of genres and keywords -- remove commas and convert to lower 
working_df["tags"] = (df.genres + df.keywords).str.lower().str.replace(",","")
working_df.head()
# Out:
#              id                      title          genres  \
# 663699  1471989                    88 days        Thriller
# 625587  1513321               Curious Love         Romance
# 235483  1467898        Call of the Vulture   Drama, Comedy
# 288442  1468429  Being Friends with a Rock  Comedy, Action
# 328029  1494858                   Sunburst   Comedy, Drama
#
#                                                  keywords  \
# 663699                                   time loop, guilt
# 625587                                    lesbian erotica
# 235483  friendship, haunted by the past, rise to fame,...
# 288442                          revenge, buddy film, rock
# 328029                    dry, student film, black comedy
#
#                                                  overview original_language  \
# 663699  Damien, a young man recently widowed, wakes up...                en
# 625587  Charming blonde Sweet Lina is lounging on the ...                en
# ...

# %%
# creating a much smaller subset for the recommendation system to reduce load on computing resources
reduced_df = working_df.iloc[:10000]
reduced_df.head()
# Out:
#              id                      title          genres  \
# 663699  1471989                    88 days        Thriller
# 625587  1513321               Curious Love         Romance
# 235483  1467898        Call of the Vulture   Drama, Comedy
# 288442  1468429  Being Friends with a Rock  Comedy, Action
# 328029  1494858                   Sunburst   Comedy, Drama
#
#                                                  keywords  \
# 663699                                   time loop, guilt
# 625587                                    lesbian erotica
# 235483  friendship, haunted by the past, rise to fame,...
# 288442                          revenge, buddy film, rock
# 328029                    dry, student film, black comedy
#
#                                                  overview original_language  \
# 663699  Damien, a young man recently widowed, wakes up...                en
# 625587  Charming blonde Sweet Lina is lounging on the ...                en
# ...

# %%
# creating another subset for training th cosine similarity model
model_df = reduced_df[["id","title","tags"]].reset_index()
model_df.head()
# Out:
#     index       id                      title  \
# 0  663699  1471989                    88 days
# 1  625587  1513321               Curious Love
# 2  235483  1467898        Call of the Vulture
# 3  288442  1468429  Being Friends with a Rock
# 4  328029  1494858                   Sunburst
#
#                                                 tags
# 0                            thrillertime loop guilt
# 1                             romancelesbian erotica
# 2  drama comedyfriendship haunted by the past ris...
# 3               comedy actionrevenge buddy film rock
# 4          comedy dramadry student film black comedy

# %%
# drop the original index column
model_df.drop(columns=['index'], inplace=True)

# %%
model_df.head()
# Out:
#         id                      title  \
# 0  1471989                    88 days
# 1  1513321               Curious Love
# 2  1467898        Call of the Vulture
# 3  1468429  Being Friends with a Rock
# 4  1494858                   Sunburst
#
#                                                 tags
# 0                            thrillertime loop guilt
# 1                             romancelesbian erotica
# 2  drama comedyfriendship haunted by the past ris...
# 3               comedy actionrevenge buddy film rock
# 4          comedy dramadry student film black comedy

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#initialize vectorizer
tfidf = TfidfVectorizer(stop_words="english")

# transform tags to vectors
tfidf_matrix= tfidf.fit_transform(model_df["tags"])

# %%
similarities = cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
# function for recommend button
def get_recommendations(title):
    # Ensure exact match and safe indexing
    match = model_df[model_df['title'].str.lower() == title.lower()]
    if match.empty:
        return pd.DataFrame()

    index = match.index[0]

    similarity_scores = similarities[index]
    movie_scores = list(enumerate(similarity_scores))
    sorted_scores = sorted(movie_scores, key=lambda x: x[1], reverse=True)
    top_movies = sorted_scores[1:11]
    top_indices = [i for i, score in top_movies]

    return model_df.iloc[top_indices]

# %%
recommendations_df = get_recommendations("Sunburst")
recommendations_df
# Out:
#            id                     title  \
# 9656  1257255            Killer Friends
# 8063  1124928              The Roommate
# 8332  1122989        I Love Your Knife!
# 7480  1146220                 The Stiff
# 4885  1198879  Ralph Barbosa: Cowabunga
# 1476  1374396              Interruption
# 7220  1137729     Cut from the Same Cow
# 8105  1117942               Out of Love
# 8118  1117939                   Cricket
# 8327  1117865           Inconsequential
#
#                                                    tags
# 9656      comedy drama thrillerdark comedy film student
# 8063          comedy dramashort film student film drama
# 8332  horror comedy romanceslasher horror comedy stu...
# 7480  comedydark comedy short film student film indi...
# 4885                       comedystand-up comedy comedy
# 1476                       dramashort film student film
# 7220                       dramashort film student film
# 8105                       dramashort film student film
# ...

# %%
# recently added movies
reduced_df.head(6)["title"]
# Out:
# 663699                      88 days
# 625587                 Curious Love
# 235483          Call of the Vulture
# 288442    Being Friends with a Rock
# 328029                     Sunburst
# 309194                   Bat-killer
# Name: title, dtype: object

# %%
# popular movies
reduced_df.sort_values(by="popularity", ascending=False)[["title","popularity"]].head()
# Out:
#                   title  popularity
# 3872        Blue Beetle    2994.357
# 5049       Gran Turismo    2680.593
# 7929         The Nun II    1692.778
# 2129  Meg 2: The Trench    1567.273
# 9966        Retribution    1547.220

# %%
# viewers choice
reduced_df.sort_values(by="vote_count", ascending=False)[["title","vote_count"]].head()
# Out:
#                                    title  vote_count
# 527          The Super Mario Bros. Movie        6743
# 825                               Barbie        5074
# 849       Guardians of the Galaxy Vol. 3        4941
# 905                 John Wick: Chapter 4        4639
# 953  Spider-Man: Across the Spider-Verse        4394

# %%
model_df
# Out:
#            id                      title  \
# 0     1471989                    88 days
# 1     1513321               Curious Love
# 2     1467898        Call of the Vulture
# 3     1468429  Being Friends with a Rock
# 4     1494858                   Sunburst
# ...       ...                        ...
# 9995  1104771                   My House
# 9996  1096472             Microchip Wars
# 9997  1097714       Frontier Documentary
# 9998   838082              Dano Lunático
# 9999  1102144    Women Seeking Women 191
#
#                                                    tags
# 0                               thrillertime loop guilt
# 1                                romancelesbian erotica
# 2     drama comedyfriendship haunted by the past ris...
# 3                  comedy actionrevenge buddy film rock
# 4             comedy dramadry student film black comedy
# ...                                                 ...
# 9995               horror mystery thrillerfound footage
# ...

# %%
### function to fetch movie poster
import requests

api_key = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2MmNkMWNlNjc3ZDY5Y2QzYzhmZDIxMjlmOWRkZjE2MSIsIm5iZiI6MTc0OTM4OTU1MC40MTI5OTk5LCJzdWIiOiI2ODQ1OTBlZTBlZTdlMGI2NjIzNDIzZjEiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.1ZpxLI6s9zlLWVPGaapignJwpMxLjNvAbLJIYqAVeAM"  
size = "w500"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json;charset=utf-8"
}

def get_poster_url(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}"
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        poster_path = data.get("poster_path")
        if poster_path:
            return f"https://image.tmdb.org/t/p/{size}{poster_path}"
        else:
            pass
    else:
        pass
    
    return None

# %%
model_df["poster_url"] = model_df["id"].apply(get_poster_url)

# %%
# read the old updated model df instead of running the get url function again
app_df = pd.read_csv("model_df_updated.csv")
app_df.head()
# Out:
#         id                      title  \
# 0  1471989                    88 days
# 1  1513321               Curious Love
# 2  1494858                   Sunburst
# 3  1467898        Call of the Vulture
# 4  1468429  Being Friends with a Rock
#
#                                                 tags  \
# 0                            thrillertime loop guilt
# 1                             romancelesbian erotica
# 2          comedy dramadry student film black comedy
# 3  drama comedyfriendship haunted by the past ris...
# 4               comedy actionrevenge buddy film rock
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w500/ilRN1ewymDHydE...
# 1  https://image.tmdb.org/t/p/w500/4I5hk16UmGOKPn...
# 2  https://image.tmdb.org/t/p/w500/2WSQOUyos9hS3B...
# 3  https://image.tmdb.org/t/p/w500/abHpRTdWz16QaD...
# 4  https://image.tmdb.org/t/p/w500/4g1PBRNt9N0W4e...

# %%
app_df.isna().sum()
# Out:
# id              0
# title           0
# tags            0
# poster_url    959
# dtype: int64

# %%
app_df[app_df["poster_url"].isnull()]
# Out:
#            id                                    title  \
# 26    1465448      wellington more like welling not on
# 33    1477601                               Cobra Sigh
# 42    1464649                          2 guys fighting
# 43    1464642                          2 guys fighting
# 58    1484851                        Resident Playbook
# ...       ...                                      ...
# 9914  1288911                Dante’s Zany Misadventure
# 9943  1376590                            The Professor
# 9947  1071097  Chronicles of a sodium chloride grinder
# 9951  1308198                            Erasmus Diary
# 9990  1098638                             en el living
#
#                                                    tags poster_url
# 26    comedy music adventurerugby travel wellington ...        NaN
# 33     drama action comedymartial arts bullying divorce        NaN
# 42                                   action comedyfight        NaN
# ...

# %%
# drop all null columns
app_df.dropna(inplace=True)

# %%
app_df.isna().sum()
# Out:
# id            0
# title         0
# tags          0
# poster_url    0
# dtype: int64

# %%
app_df.shape
# Out:
# (9041, 4)

# %%
app_df

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#initialize vectorizer
tfidf_ = TfidfVectorizer(stop_words="english")

# transform tags to vectors
tfidf_matrix_ = tfidf_.fit_transform(app_df["tags"])

# %%
# similarities
sim = cosine_similarity(tfidf_matrix_,tfidf_matrix_)

# %%
# exporting df and similarities to be used in app
import pickle

with open("movie_data.pkl", "wb") as file:
    pickle.dump((app_df, sim),file)

# %%
filtered_df = app_df[app_df["tags"].str.contains('adult', case=False, na=False)]
filtered_df
# Out:
#            id                                              title  \
# 379   1441241                       Picha, Envers et contre tout
# 722   1421938                                 First Thing Sunday
# 789   1447382                            Those That Go Unnoticed
# 794   1404214                                       Life Eternal
# 958   1448066                                       Business Bag
# 1164  1371430                                  With Love, Lottie
# 1622  1371739                            The Small Victorian Boy
# 2366  1315711                                     Clocking The T
# 2542  1439284                                            Zom-Dad
# 2622  1405173             A Jellyfish Who is Afraid of the Ocean
# 2698  1444669  Rin Azuma Is Seriously Cumming!! Hard And Tigh...
# 2822  1314910                                      Dear Students
# 3218  1280284                                        FLORA PARTY
# ...
